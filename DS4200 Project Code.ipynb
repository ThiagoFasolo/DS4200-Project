# %%
import pandas as pd
import altair as alt
import pandas as pd
import numpy as np
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
# --- Load files (paths from your upload notes) ---
returns = pd.read_csv("20250810_funds_open-end-fund-performance.csv")
profiles = pd.read_csv("20250810_funds_open-end-fund-profile.csv")

# %%
returns.head()
# Out:
#    Fund ID                                          Fund Name  \
# 0    47813   DNCA Invest Alpha Bonds UCITS Fund - Class B EUR
# 1    12160                                 Hudson Bay Fund LP
# 2    10313  Renaissance Institutional Equities Fund Intern...
# 3    21959                     Pershing Square Holdings, Ltd.
# 4    22013  Algebris Financial Credit UCITS Fund - Class I...
#
#                          Manager Name  Manager ID  Fund AuM (m) Fund AuM Date  \
# 0                        DNCA Finance  2145868778       22707.8      8/1/2025
# 1       Hudson Bay Capital Management  2145862151        6108.8      8/1/2025
# 2            Renaissance Technologies  2145861123       20463.0      8/1/2025
# 3  Pershing Square Capital Management  2145861095       19194.2      9/1/2025
# 4                Algebris Investments  2145862644       18732.0      9/1/2025
#
#    Strategy AuM (m) Strategy AuM Date Last 3 Months Worst Month  ...  \
# 0           22707.8          8/1/2025         0.45%      -5.42%  ...
# 1           20847.5          8/1/2025         2.34%      -3.53%  ...
# 2           20463.0          8/1/2025        -0.24%      -9.49%  ...
# 3           19194.2          9/1/2025         6.75%     -12.52%  ...
# 4           18732.0          9/1/2025         2.31%     -11.05%  ...
#
#   Monthly NAV Jan 2025 Monthly NAV Feb 2025 Monthly NAV Mar 2025  \
# 0                123.5                124.5                124.5
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                 75.1                 75.4                 70.1
# 4                213.6                215.7                213.3
#
#   Monthly NAV Apr 2025 Monthly NAV May 2025 Monthly NAV Jun 2025  \
# 0                124.5                125.2                126.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                 71.3                 79.0                 81.8
# 4                213.3                215.8                218.3
#
#   Monthly NAV Jul 2025 Monthly NAV Aug 2025 Monthly NAV Sep 2025  \
# 0                126.3                126.5                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                 79.8                 83.9                 87.2
# 4                220.8                221.4                223.3
#
#   Monthly NAV Oct 2025
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 83 columns]

# %%
profiles.head()
# Out:
#    Fund ID                                          Fund Name  Fund AuM (m)  \
# 0    47813   DNCA Invest Alpha Bonds UCITS Fund - Class B EUR       22707.8
# 1    12160                                 Hudson Bay Fund LP        6108.8
# 2    10313  Renaissance Institutional Equities Fund Intern...       20463.0
# 3    21959                     Pershing Square Holdings, Ltd.       19194.2
# 4    22013  Algebris Financial Credit UCITS Fund - Class I...       18732.0
#
#   Fund AuM Date  Strategy AuM (m) Strategy AuM Date Monthly Return Jul 2025  \
# 0        8/1/25           22707.8            8/1/25                   0.23%
# 1        8/1/25           20847.5            8/1/25                   0.99%
# 2        8/1/25           20463.0            8/1/25                  -4.50%
# 3        9/1/25           19194.2            9/1/25                  -2.38%
# 4        9/1/25           18732.0            9/1/25                   1.15%
#
#   Monthly Return Aug 2025 Monthly Return Sep 2025   Fund Structure  ...  \
# 0                   0.22%                     NaN            UCITS  ...
# 1                   1.33%                     NaN    Open-End Fund  ...
# 2                   4.46%                  -2.89%  Commingled Fund  ...
# 3                   5.05%                   4.10%                -  ...
# 4                   0.25%                   0.89%            UCITS  ...
#
#                  Custodian                         Legal Advisors  \
# 0              BNP Paribas                                      -
# 1                        -  Paul Weiss Rifkind Wharton & Garrison
# 2  BNY Mellon, Wells Fargo             Katten Muchin Rosenman LLP
# 3                        -                                      -
# 4              BNP Paribas                         Dillon Eustace
#
#            Telephone            Address 1    Address 2      City  \
# 0  +33 1 58 62 55 00    19, place Vendôme            -     Paris
# 1    +1 475 900 9550     290 Harbor Drive    3rd Floor  Stamford
# 2    +1 212 829 4460     800 Third Avenue            -  New York
# 3    +1 212 813 3700  787 Eleventh Avenue    9th Floor  New York
# 4   +44 2031 962 450    11 Waterloo Place  First Floor    London
#
#   Zip/Post Code         Country      General Email Address  \
# 0         75001          France  dnca@dnca-investments.com
# 1         06902   United States    ir@hudsonbaycapital.com
# 2         10022   United States      renfundweb@rentec.com
# 3         10019   United States               ir@persq.com
# 4      SW1Y 4AU  United Kingdom     enquiries@algebris.com
#
#                                              Website
# 0                  https://www.dnca-investments.com/
# 1                  https://www.hudsonbaycapital.com/
# 2                            https://www.rentec.com/
# 3  https://pershingsquareholdings.com/about/persh...
# 4                          https://www.algebris.com/
#
# [5 rows x 61 columns]

# %%
# 1) Columns to keep (paste exactly as in your DataFrame)
returns_cols = [
    'Fund ID','YTD','Annualized Returns (Since Inception)', 'Fund AuM (m)','Sharpe Ratio (Since Inception)','Sortino Ratio','Maximum Drawdown',
    'Annualized Standard Deviation (Since Inception)','Monthly Return Sep 2024','Monthly Return Oct 2024','Monthly Return Nov 2024',
    'Monthly Return Dec 2024','Monthly Return Jan 2025','Monthly Return Feb 2025','Monthly Return Mar 2025','Monthly Return May 2025',
    'Monthly Return Jun 2025', 'Monthly Return Jul 2025','Monthly Return Aug 2025','Monthly Return Sep 2025','Total Return'
]
# Align with actual columns present (avoids KeyError if any missing)
returns_keep_cols = [c for c in returns_cols if c in returns.columns]
returns_clean= returns[returns_keep_cols].copy()
returns_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7830 entries, 0 to 7829
# Data columns (total 21 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Fund ID                                          7830 non-null   int64
#  1   YTD                                              7717 non-null   object
#  2   Annualized Returns (Since Inception)             7707 non-null   object
#  3   Fund AuM (m)                                     6301 non-null   float64
#  4   Sharpe Ratio (Since Inception)                   7704 non-null   float64
#  5   Sortino Ratio                                    7603 non-null   float64
#  6   Maximum Drawdown                                 7825 non-null   object
#  7   Annualized Standard Deviation (Since Inception)  7702 non-null   object
#  8   Monthly Return Sep 2024                          7671 non-null   object
#  9   Monthly Return Oct 2024                          7701 non-null   object
#  10  Monthly Return Nov 2024                          7696 non-null   object
#  11  Monthly Return Dec 2024                          7697 non-null   object
#  12  Monthly Return Jan 2025                          7647 non-null   object
#  13  Monthly Return Feb 2025                          7681 non-null   object
#  14  Monthly Return Mar 2025                          7681 non-null   object
#  15  Monthly Return May 2025                          7633 non-null   object
#  16  Monthly Return Jun 2025                          7595 non-null   object
#  17  Monthly Return Jul 2025                          7420 non-null   object
#  18  Monthly Return Aug 2025                          7121 non-null   object
#  19  Monthly Return Sep 2025                          3103 non-null   object
#  20  Total Return                                     7702 non-null   object
# dtypes: float64(3), int64(1), object(17)
# memory usage: 1.3+ MB

# %%
# 1) Columns to keep (paste exactly as in your DataFrame)
profile_cols = [
    'Fund ID','Fund Name', 'Manager Name','Fund Aum (m)', 'Fund Structure', 
    'Inception Date', 'Primary Strategy', 'Secondary Strategy', 'City', 'Country']

# Align with actual columns present (avoids KeyError if any missing)
profile_keep_cols = [c for c in profile_cols if c in profiles.columns]
profiles_clean= profiles[profile_keep_cols].copy()
profiles_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7830 entries, 0 to 7829
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fund ID             7830 non-null   int64
#  1   Fund Name           7830 non-null   object
#  2   Manager Name        7830 non-null   object
#  3   Fund Structure      7825 non-null   object
#  4   Inception Date      7569 non-null   object
#  5   Primary Strategy    7830 non-null   object
#  6   Secondary Strategy  7830 non-null   object
#  7   City                7830 non-null   object
#  8   Country             7830 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 550.7+ KB

# %%
df = pd.merge(profiles_clean, returns_clean,on="Fund ID", how="inner")
df.head()
# Out:
#    Fund ID                                          Fund Name  \
# 0    47813   DNCA Invest Alpha Bonds UCITS Fund - Class B EUR
# 1    12160                                 Hudson Bay Fund LP
# 2    10313  Renaissance Institutional Equities Fund Intern...
# 3    21959                     Pershing Square Holdings, Ltd.
# 4    22013  Algebris Financial Credit UCITS Fund - Class I...
#
#                          Manager Name   Fund Structure Inception Date  \
# 0                        DNCA Finance            UCITS       12/14/17
# 1       Hudson Bay Capital Management    Open-End Fund         1/1/06
# 2            Renaissance Technologies  Commingled Fund         8/1/05
# 3  Pershing Square Capital Management                -         1/1/13
# 4                Algebris Investments            UCITS         9/3/12
#
#       Primary Strategy                                 Secondary Strategy  \
# 0  Fixed Income/Credit                              Multi-Strategy Credit
# 1       Multi-Strategy  Event Driven, Merger Arbitrage, Convertible Ar...
# 2               Equity                                   Long Bias Equity
# 3         Event Driven                                           Activist
# 4       Relative Value                             Fixed Income Arbitrage
#
#        City         Country     YTD  ... Monthly Return Dec 2024  \
# 0     Paris          France   3.62%  ...                   0.02%
# 1  Stamford   United States   5.88%  ...                   0.85%
# 2  New York   United States  10.36%  ...                  -1.14%
# 3  New York   United States  23.25%  ...                  -0.42%
# 4    London  United Kingdom   5.75%  ...                   0.59%
#
#    Monthly Return Jan 2025  Monthly Return Feb 2025  Monthly Return Mar 2025  \
# 0                    1.10%                    0.83%                   -0.02%
# 1                    1.52%                    0.57%                   -0.66%
# 2                    7.38%                    4.12%                    0.72%
# 3                    5.64%                    0.33%                   -6.80%
# 4                    1.11%                    0.98%                   -1.07%
#
#   Monthly Return May 2025 Monthly Return Jun 2025 Monthly Return Jul 2025  \
# 0                   0.59%                   0.62%                   0.23%
# 1                   1.07%                   0.97%                   0.99%
# 2                   1.92%                  -3.62%                  -4.50%
# 3                  10.80%                   3.70%                  -2.38%
# 4                   1.20%                   1.15%                   1.15%
#
#   Monthly Return Aug 2025 Monthly Return Sep 2025 Total Return
# 0                   0.22%                     NaN       26.38%
# 1                   1.33%                     NaN      565.57%
# 2                   4.46%                  -2.89%      523.58%
# 3                   5.05%                   4.10%      292.60%
# 4                   0.25%                   0.89%      123.36%
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Fund ID', 'Fund Name', 'Manager Name', 'Fund Structure',
#        'Inception Date', 'Primary Strategy', 'Secondary Strategy', 'City',
#        'Country', 'YTD', 'Annualized Returns (Since Inception)',
#        'Fund AuM (m)', 'Sharpe Ratio (Since Inception)', 'Sortino Ratio',
#        'Maximum Drawdown', 'Annualized Standard Deviation (Since Inception)',
#        'Monthly Return Sep 2024', 'Monthly Return Oct 2024',
#        'Monthly Return Nov 2024', 'Monthly Return Dec 2024',
#        'Monthly Return Jan 2025', 'Monthly Return Feb 2025',
#        'Monthly Return Mar 2025', 'Monthly Return May 2025',
#        'Monthly Return Jun 2025', 'Monthly Return Jul 2025',
#        'Monthly Return Aug 2025', 'Monthly Return Sep 2025', 'Total Return'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7830 entries, 0 to 7829
# Data columns (total 29 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Fund ID                                          7830 non-null   int64
#  1   Fund Name                                        7830 non-null   object
#  2   Manager Name                                     7830 non-null   object
#  3   Fund Structure                                   7825 non-null   object
#  4   Inception Date                                   7569 non-null   object
#  5   Primary Strategy                                 7830 non-null   object
#  6   Secondary Strategy                               7830 non-null   object
#  7   City                                             7830 non-null   object
#  8   Country                                          7830 non-null   object
#  9   YTD                                              7717 non-null   object
#  10  Annualized Returns (Since Inception)             7707 non-null   object
#  11  Fund AuM (m)                                     6301 non-null   float64
#  12  Sharpe Ratio (Since Inception)                   7704 non-null   float64
#  13  Sortino Ratio                                    7603 non-null   float64
#  14  Maximum Drawdown                                 7825 non-null   object
#  15  Annualized Standard Deviation (Since Inception)  7702 non-null   object
#  16  Monthly Return Sep 2024                          7671 non-null   object
#  17  Monthly Return Oct 2024                          7701 non-null   object
#  18  Monthly Return Nov 2024                          7696 non-null   object
#  19  Monthly Return Dec 2024                          7697 non-null   object
#  20  Monthly Return Jan 2025                          7647 non-null   object
#  21  Monthly Return Feb 2025                          7681 non-null   object
#  22  Monthly Return Mar 2025                          7681 non-null   object
#  23  Monthly Return May 2025                          7633 non-null   object
#  24  Monthly Return Jun 2025                          7595 non-null   object
#  25  Monthly Return Jul 2025                          7420 non-null   object
#  26  Monthly Return Aug 2025                          7121 non-null   object
#  27  Monthly Return Sep 2025                          3103 non-null   object
#  28  Total Return                                     7702 non-null   object
# dtypes: float64(3), int64(1), object(25)
# memory usage: 1.7+ MB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2703 entries, 2 to 7829
# Data columns (total 29 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Fund ID                                          2703 non-null   int64
#  1   Fund Name                                        2703 non-null   object
#  2   Manager Name                                     2703 non-null   object
#  3   Fund Structure                                   2703 non-null   object
#  4   Inception Date                                   2703 non-null   object
#  5   Primary Strategy                                 2703 non-null   object
#  6   Secondary Strategy                               2703 non-null   object
#  7   City                                             2703 non-null   object
#  8   Country                                          2703 non-null   object
#  9   YTD                                              2703 non-null   object
#  10  Annualized Returns (Since Inception)             2703 non-null   object
#  11  Fund AuM (m)                                     2703 non-null   float64
#  12  Sharpe Ratio (Since Inception)                   2703 non-null   float64
#  13  Sortino Ratio                                    2703 non-null   float64
#  14  Maximum Drawdown                                 2703 non-null   object
#  15  Annualized Standard Deviation (Since Inception)  2703 non-null   object
#  16  Monthly Return Sep 2024                          2703 non-null   object
#  17  Monthly Return Oct 2024                          2703 non-null   object
#  18  Monthly Return Nov 2024                          2703 non-null   object
#  19  Monthly Return Dec 2024                          2703 non-null   object
#  20  Monthly Return Jan 2025                          2703 non-null   object
#  21  Monthly Return Feb 2025                          2703 non-null   object
#  22  Monthly Return Mar 2025                          2703 non-null   object
#  23  Monthly Return May 2025                          2703 non-null   object
#  24  Monthly Return Jun 2025                          2703 non-null   object
#  25  Monthly Return Jul 2025                          2703 non-null   object
#  26  Monthly Return Aug 2025                          2703 non-null   object
#  27  Monthly Return Sep 2025                          2703 non-null   object
#  28  Total Return                                     2703 non-null   object
# dtypes: float64(3), int64(1), object(25)
# memory usage: 633.5+ KB

# %%
df.to_csv("my_dataframe_with_index.csv", index=False)

# %%
import pandas as pd
import altair as alt

# --- detect a strategy column ---
strategy_col = next((c for c in ["strategy","Strategy","Primary Strategy","Fund Strategy","Main Strategy"]
                     if c in df.columns), None)
assert strategy_col is not None, "No strategy column found."

# --- tidy ---
rp = df.rename(columns={
    "Manager Name":"manager",
    "Sharpe Ratio (Since Inception)":"sharpe",
    "Sortino Ratio":"sortino",
    "Annualized Standard Deviation (Since Inception)":"stdev",
    strategy_col: "strategy",
})
rp["stdev"] = pd.to_numeric(rp["stdev"].astype(str).str.replace("%","", regex=False),
                            errors="coerce")/100

# --- aggregate to one row per manager ---
def _mode_or_first(s: pd.Series):
    m = s.mode()
    return m.iloc[0] if not m.empty else s.dropna().iloc[0] if s.dropna().size else None

mgr = (
    rp.dropna(subset=["manager","sharpe","stdev"])
      .groupby("manager", as_index=False)
      .agg(sharpe=("sharpe","mean"),
           sortino=("sortino","mean"),
           stdev=("stdev","mean"),
           strategy=("strategy", _mode_or_first),
           n_funds=("manager","size"))
)

# --- chart: each point = manager, color = strategy ---
select_strat = alt.selection_multi(fields=["strategy"], bind="legend")  # click legend to filter/highlight

chart = (
  alt.Chart(mgr)
    .mark_circle(size=110, opacity=0.9, stroke='black', strokeWidth=0.25)
    .encode(
        x=alt.X("stdev:Q",  title="Avg Risk (Stdev)", axis=alt.Axis(format="%")),
        y=alt.Y("sharpe:Q", title="Avg Sharpe"),
        color=alt.Color("strategy:N", title="Strategy", legend=alt.Legend(symbolLimit=30)),
        tooltip=[
            alt.Tooltip("manager:N",  title="Manager"),
            alt.Tooltip("strategy:N", title="Strategy"),
            alt.Tooltip("sharpe:Q",   format=".2f"),
            alt.Tooltip("sortino:Q",  format=".2f"),
            alt.Tooltip("stdev:Q",    format=".1%"),
            alt.Tooltip("n_funds:Q",  title="# Funds")
        ],
        opacity=alt.condition(select_strat, alt.value(1), alt.value(0.25))
    )
    .properties(width=780, height=440, title="Managers: Risk vs. Sharpe (color = Strategy)")
    .add_selection(select_strat)
    .interactive()
)

chart
# Out:
# /var/folders/3z/qc34j53n3mv8yp0p4bksgypm0000gn/T/ipykernel_37986/1768090761.py:36: AltairDeprecationWarning:
# Deprecated since `altair=5.0.0`. Use selection_point instead.
#   select_strat = alt.selection_multi(fields=["strategy"], bind="legend")  # click legend to filter/highlight
# /var/folders/3z/qc34j53n3mv8yp0p4bksgypm0000gn/T/ipykernel_37986/1768090761.py:56: AltairDeprecationWarning:
# Deprecated since `altair=5.0.0`. Use add_params instead.
#   .add_selection(select_strat)
# alt.Chart(...)

# %%
rr = df[[
    "Fund Name","Fund AuM (m)","Sharpe Ratio (Since Inception)",
    "Annualized Returns (Since Inception)","Annualized Standard Deviation (Since Inception)"
]].rename(columns={
    "Fund AuM (m)":"aum", "Sharpe Ratio (Since Inception)":"sharpe",
    "Annualized Returns (Since Inception)":"ret", "Annualized Standard Deviation (Since Inception)":"stdev"
})

# quick percent coercion (works for numbers or '12.3%')
for c in ["ret","stdev"]:
    rr[c] = pd.to_numeric(rr[c].astype(str).str.replace("%","", regex=False), errors="coerce")/100

rr = rr.dropna(subset=["ret","stdev","sharpe","aum"])
xmax = rr["stdev"].quantile(0.99); ymin, ymax = rr["ret"].quantile([0.01,0.99])
brush = alt.selection_interval()   # drag to zoom/select

chart1 = (
  alt.Chart(rr.query("stdev<=@xmax and @ymin<=ret<=@ymax"))
    .mark_circle(opacity=0.75)
    .encode(
        x=alt.X("stdev:Q", title="Risk (Ann. Stdev)", axis=alt.Axis(format="%")),
        y=alt.Y("ret:Q",   title="Return (Ann.)",     axis=alt.Axis(format="%")),
        size=alt.Size("aum:Q", title="AuM (m)", scale=alt.Scale(range=[20,350])),
        color=alt.Color("sharpe:Q", title="Sharpe", scale=alt.Scale(scheme="viridis")),
        tooltip=["Fund Name","sharpe:Q","aum:Q","ret:Q","stdev:Q"]
    )
    .properties(width=700, height=430, title="Risk–Return (AuM size, Sharpe color)")
    .add_selection(brush)
    .interactive()
)
chart1
# Out:
# /var/folders/3z/qc34j53n3mv8yp0p4bksgypm0000gn/T/ipykernel_37986/322372388.py:28: AltairDeprecationWarning:
# Deprecated since `altair=5.0.0`. Use add_params instead.
#   .add_selection(brush)
# alt.Chart(...)
