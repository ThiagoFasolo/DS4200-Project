# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("20250810_funds_open-end-fund-profile.csv")


# Quick check of the column names
print(data.columns)

# Make sure the columns exist and have numeric data
x = data["Fund AuM (m)"]
y = data["Monthly Return Jul 2025"]

# Basic scatter plot (better for continuous variables)
plt.figure(figsize=(8,5))
plt.scatter(x, y)
plt.xlabel("Fund AuM (millions)")
plt.ylabel("Monthly Return (July 2025)")
plt.title("Relationship between Fund AuM and July 2025 Monthly Return")
plt.show()
# Out:
# Index(['Fund ID', 'Fund Name', 'Fund AuM (m)', 'Fund AuM Date',
#        'Strategy AuM (m)', 'Strategy AuM Date', 'Monthly Return Jul 2025',
#        'Monthly Return Aug 2025', 'Monthly Return Sep 2025', 'Fund Structure',
#        'Open to Investment', 'Inception Date', 'Domicile', 'Domicile Status',
#        'Attribute', 'Master Shareclass', 'Master Shareclass Name',
#        'Master Shareclass ID', 'Shuttered', 'Shuttered Date',
#        'ISIN or Ref Code', 'Fund Capacity (m)', 'Planned Launch Date',
#        'Manager Name', 'Manager ID', 'Manager Currency',
#        'Manager Total AuM (m)', 'Manager Total AuM As Of',
#        'Manager Hedge AuM (m)', 'Manager Hedge AuM As Of', 'Primary Strategy',
#        'Secondary Strategy', 'Approach', 'Investment Region',
#        'Primary Industries', 'Secondary Industries', 'Asset Class',
#        'Strategy Description', 'Management Fee', 'Performance Fee',
#        'Hurdle Rate', 'High Water Mark', 'Minimum Investment Currency',
# ...
